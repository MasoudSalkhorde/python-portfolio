# %%
import random

CHOICES = ['rock', 'paper', 'scisors']

class Player:
    def __init__(self):
        self.score = 0
        
    def player_move(self):
        return input("What is your choise?")

# %%
player = Player()
choice = player.player_move()

# %%
choice
# Out:
# 'rock'
